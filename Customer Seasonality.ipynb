# %%
import pandas as pd

# %%
cs = pd.read_csv("cust_season_N.csv", usecols = ["cust_nbr","year","fisc_wk_id","ttl_cases"])

# %%
cs.shape
# Out:
# (141778, 4)

# %%
cs.drop_duplicates()
# Out:
#         cust_nbr  year  fisc_wk_id  ttl_cases
# 0          36111  2021      202218        1.0
# 2          36111  2021      202219        1.0
# 7          36111  2021      202220        1.0
# 8          36111  2021      202221        1.0
# 9          36475  2021      202218        1.0
# ...          ...   ...         ...        ...
# 141773    952754  2023      202329        1.0
# 141774    952754  2023      202330        1.0
# 141775    952754  2023      202332        1.0
# 141776    952754  2023      202333        2.0
# 141777    952754  2023      202341        1.0
#
# [84331 rows x 4 columns]

# %%
cs.head(60)
# Out:
#     cust_nbr  year  fisc_wk_id  ttl_cases
# 0      36111  2021      202218        1.0
# 1      36111  2021      202218        1.0
# 2      36111  2021      202219        1.0
# 3      36111  2021      202219        1.0
# 4      36111  2021      202219        1.0
# 5      36111  2021      202219        1.0
# 6      36111  2021      202219        1.0
# 7      36111  2021      202220        1.0
# 8      36111  2021      202221        1.0
# 9      36475  2021      202218        1.0
# 10     36475  2021      202218        2.0
# 11     36475  2021      202218        7.0
# 12     36475  2021      202218        2.0
# 13     36475  2021      202218        5.0
# 14     36475  2021      202218        2.0
# 15     36475  2021      202218        4.0
# 16     36475  2021      202218        2.0
# 17     36475  2021      202218       12.0
# 18     36475  2021      202218        1.0
# 19     36475  2021      202218        1.0
# 20     36475  2021      202218        2.0
# ...

# %%
cs["ttl_cases"].value_counts()
# Out:
# 1.000     66612
# 2.000     27964
# 3.000     12509
# 4.000      8885
# 5.000      4829
#           ...
# 6.250         1
# 7.333         1
# 18.166        1
# 1.416         1
# 10.250        1
# Name: ttl_cases, Length: 184, dtype: int64
